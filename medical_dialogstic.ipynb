# %%
# !pip install -U scikit-fuzzy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 993 kB 3.2 MB/s
# ...
#   Created wheel for scikit-fuzzy: filename=scikit_fuzzy-0.4.2-py3-none-any.whl size=894089 sha256=b516d5addd778d18312ecdd8dc484928717564354e90e931b34881a960e719f7
#   Stored in directory: /root/.cache/pip/wheels/d5/74/fc/38588a3d2e3f34f74588e6daa3aa5b0a322bd6f9420a707131
# Successfully built scikit-fuzzy
# ...

# %%
import numpy as np
import skfuzzy as fuzz
from skfuzzy import control as ctrl
import matplotlib.pyplot as plt
#input variable 
fever = ctrl.Antecedent(np.arange(0,10.1,0.1),'fever')
headache = ctrl.Antecedent(np.arange(0,10.1,0.1),'headache')
nause = ctrl.Antecedent(np.arange(0,10.1,0.1),'nause')
vomiting = ctrl.Antecedent(np.arange(0,10.1,0.1),'vomiting')
jaundice = ctrl.Antecedent(np.arange(0,10.1,0.1),'jaundice')
enlarge_liver = ctrl.Antecedent(np.arange(0,10.1,0.1),'enlarge_liver')
joint_pain = ctrl.Antecedent(np.arange(0,10.1,0.1),'joint_pain')
body_weakness = ctrl.Antecedent(np.arange(0,10.1,0.1),'body_weakness')
dizziness = ctrl.Antecedent(np.arange(0,10.1,0.1),'dizziness')
loss_of_appentite = ctrl.Antecedent(np.arange(0,10.1,0.1),'loss_of_appentite')
MP = ctrl.Antecedent(np.arange(0,10.1,0.1),'MP')
MP = ctrl.Antecedent(np.arange(0,10.1,0.1),'MP')
#output need to predict
conclusion = ctrl.Consequent(np.arange(0,10.1,0.1),'conclusion')

fever['mild'] = fuzz.trimf(fever.universe,[0,1.5,3])
fever['moderate'] = fuzz.trimf(fever.universe,[3,4.5,6])
fever['severe'] = fuzz.trimf(fever.universe,[6,7,8])
fever['very_severe'] = fuzz.trimf(fever.universe,[8,9,10])
fever.view()

headache['mild'] = fuzz.trimf(headache.universe,[0,1.5,3])
headache['moderate'] = fuzz.trimf(headache.universe,[3,4.5,6])
headache['severe'] = fuzz.trimf(headache.universe,[6,7,8])
headache['very_severe'] = fuzz.trimf(headache.universe,[8,9,10])
headache.view()

nause['mild'] = fuzz.trimf(nause.universe,[0,1.5,3])
nause['moderate'] = fuzz.trimf(nause.universe,[3,4.5,6])
nause['severe'] = fuzz.trimf(nause.universe,[6,7,8])
nause['very_severe'] = fuzz.trimf(nause.universe,[8,9,10])
nause.view()


vomiting['mild'] = fuzz.trimf(vomiting.universe,[0,1.5,3])
vomiting['moderate'] = fuzz.trimf(vomiting.universe,[3,4.5,6])
vomiting['severe'] = fuzz.trimf(vomiting.universe,[6,7,8])
vomiting['very_severe'] = fuzz.trimf(vomiting.universe,[8,9,10])
vomiting.view()

jaundice['mild'] = fuzz.trimf(jaundice.universe,[0,1.5,3])
jaundice['moderate'] = fuzz.trimf(jaundice.universe,[3,4.5,6])
jaundice['severe'] = fuzz.trimf(jaundice.universe,[6,7,8])
jaundice['very_severe'] = fuzz.trimf(jaundice.universe,[8,9,10])
jaundice.view()

enlarge_liver['mild'] = fuzz.trimf(enlarge_liver.universe,[0,1.5,3])
enlarge_liver['moderate'] = fuzz.trimf(enlarge_liver.universe,[3,4.5,6])
enlarge_liver['severe'] = fuzz.trimf(enlarge_liver.universe,[6,7,8])
enlarge_liver['very_severe'] = fuzz.trimf(enlarge_liver.universe,[8,9,10])
enlarge_liver.view()

joint_pain['mild'] = fuzz.trimf(joint_pain.universe,[0,1.5,3])
joint_pain['moderate'] = fuzz.trimf(joint_pain.universe,[3,4.5,6])
joint_pain['severe'] = fuzz.trimf(joint_pain.universe,[6,7,8])
joint_pain['very_severe'] = fuzz.trimf(joint_pain.universe,[8,9,10])
joint_pain.view()


body_weakness['mild'] = fuzz.trimf(body_weakness.universe,[0,1.5,3])
body_weakness['moderate'] = fuzz.trimf(body_weakness.universe,[3,4.5,6])
body_weakness['severe'] = fuzz.trimf(body_weakness.universe,[6,7,8])
body_weakness['very_severe'] = fuzz.trimf(body_weakness.universe,[8,9,10])
body_weakness.view()

dizziness['mild'] = fuzz.trimf(dizziness.universe,[0,1.5,3])
dizziness['moderate'] = fuzz.trimf(dizziness.universe,[3,4.5,6])
dizziness['severe'] = fuzz.trimf(dizziness.universe,[6,7,8])
dizziness['very_severe'] = fuzz.trimf(dizziness.universe,[8,9,10])
dizziness.view()

loss_of_appentite['mild'] = fuzz.trimf(loss_of_appentite.universe,[0,1.5,3])
loss_of_appentite['moderate'] = fuzz.trimf(loss_of_appentite.universe,[3,4.5,6])
loss_of_appentite['severe'] = fuzz.trimf(loss_of_appentite.universe,[6,7,8])
loss_of_appentite['very_severe'] = fuzz.trimf(loss_of_appentite.universe,[8,9,10])
loss_of_appentite.view()

MP['mild'] = fuzz.trimf(MP.universe,[0,1.5,3])
MP['moderate'] = fuzz.trimf(MP.universe,[3,4.5,6])
MP['severe'] = fuzz.trimf(MP.universe,[6,7,8])
MP['very_severe'] = fuzz.trimf(MP.universe,[8,9,10])
MP.view()

conclusion['mild'] = fuzz.trimf(conclusion.universe,[0,1.5,3])
conclusion['moderate'] = fuzz.trimf(conclusion.universe,[3,4.5,6])
conclusion['severe'] = fuzz.trimf(conclusion.universe,[6,7,8])
conclusion['very_severe'] = fuzz.trimf(conclusion.universe,[8,9,10])
conclusion.view()

# %%
rule1 = ctrl.Rule(fever['mild'] & headache['mild'] & vomiting['mild'] & nause['mild'] & jaundice['mild'] & enlarge_liver['mild'] & body_weakness['mild'] & joint_pain['mild'] & dizziness['severe'] & loss_of_appentite['mild'] & MP['mild'], conclusion['mild'])
rule2 = ctrl.Rule(fever['moderate'] & headache['mild'] & vomiting['mild'] & nause['mild']  & jaundice['mild'] & enlarge_liver['mild'] & body_weakness['moderate'] & joint_pain['moderate'] & dizziness['severe'] & loss_of_appentite['severe'] & MP['moderate'], conclusion['moderate'])
rule3 = ctrl.Rule(fever['severe'] & headache['moderate'] & vomiting['mild'] & nause['mild']  & jaundice['mild'] & enlarge_liver['mild'] & body_weakness['severe'] & joint_pain['mild'] & dizziness['severe'] & loss_of_appentite['severe'] & MP['moderate'], conclusion['severe'])
rule4 = ctrl.Rule(fever['very_severe'] & headache['mild'] & vomiting['mild'] & nause['mild']  & jaundice['mild'] & enlarge_liver['mild'] & body_weakness['severe'] & joint_pain['severe'] & dizziness['mild'] & loss_of_appentite['mild'] & MP['severe'], conclusion['very_severe'])
rule5 = ctrl.Rule(fever['moderate'] & headache['mild'] & vomiting['moderate'] & nause['mild']  & jaundice['mild'] & enlarge_liver['mild'] & body_weakness['moderate'] & joint_pain['moderate'] & dizziness['moderate'] & loss_of_appentite['severe'] & MP['moderate'], conclusion['moderate'])
rule6 = ctrl.Rule(fever['mild'] & headache['moderate'] & vomiting['mild'] & nause['moderate']  & jaundice['mild'] & enlarge_liver['mild'] & body_weakness['mild'] & joint_pain['mild'] & dizziness['moderate'] & loss_of_appentite['mild'] & MP['mild'], conclusion['mild'])
rule7 = ctrl.Rule(fever['mild'] & headache['mild'] & vomiting['moderate'] & nause['moderate'] & jaundice['mild'] & enlarge_liver['mild'] & body_weakness['severe'] & joint_pain['severe'] & dizziness['moderate'] & loss_of_appentite['moderate'] & MP['moderate'], conclusion['severe'])
rule8 = ctrl.Rule(fever['moderate'] & headache['moderate'] & vomiting['moderate'] & nause['moderate'] & jaundice['moderate'] & enlarge_liver['moderate'] & body_weakness['moderate'] & joint_pain['moderate'] & dizziness['moderate'] & loss_of_appentite['moderate'] & MP['moderate'], conclusion['moderate'])
rule9 = ctrl.Rule(fever['moderate'] & headache['mild'] & vomiting['moderate'] & nause['moderate'] & jaundice['mild'] & enlarge_liver['severe'] & body_weakness['moderate'] & joint_pain['moderate'] & dizziness['severe'] & loss_of_appentite['moderate'] & MP['moderate'], conclusion['moderate'])
rule10 = ctrl.Rule(fever['mild'] & headache['mild'] & vomiting['moderate'] & nause['moderate'] & jaundice['mild'] & enlarge_liver['moderate'] & body_weakness['mild'] & joint_pain['mild'] & dizziness['mild'] & loss_of_appentite['mild'] & MP['mild'], conclusion['mild'])
rule11 = ctrl.Rule(fever['severe'] & headache['severe'] & vomiting['severe'] & nause['severe'] & jaundice['severe'] & enlarge_liver['severe'] & body_weakness['very_severe'] & joint_pain['severe'] & dizziness['severe'] & loss_of_appentite['severe'] & MP['moderate'], conclusion['very_severe'])
rule12 = ctrl.Rule(fever['moderate'] & headache['severe'] & vomiting['severe'] & nause['moderate'] & jaundice['moderate'] & enlarge_liver['severe'] & body_weakness['severe'] & joint_pain['moderate'] & dizziness['moderate'] & loss_of_appentite['mild'] & MP['moderate'], conclusion['severe'])
rule13 = ctrl.Rule(fever['mild'] & headache['moderate'] & vomiting['moderate'] & nause['moderate'] & jaundice['mild'] & enlarge_liver['mild'] & body_weakness['moderate'] & joint_pain['mild'] & dizziness['mild'] & loss_of_appentite['moderate'] & MP['moderate'], conclusion['moderate'])
rule14 = ctrl.Rule(fever['severe'] & headache['severe'] & vomiting['severe'] & nause['moderate'] & jaundice['severe'] & enlarge_liver['severe'] & body_weakness['severe'] & joint_pain['severe'] & dizziness['moderate'] & loss_of_appentite['moderate'] & MP['severe'], conclusion['severe'])
rule15 = ctrl.Rule(fever['mild'] & headache['mild'] & vomiting['moderate'] & nause['mild'] & jaundice['mild'] & enlarge_liver['mild'] & body_weakness['severe'] & joint_pain['mild'] & dizziness['severe'] & loss_of_appentite['severe'] & MP['moderate'], conclusion['severe'])
rule16 = ctrl.Rule(fever['very_severe'] & headache['moderate'] & vomiting['moderate'] & nause['mild'] & jaundice['severe'] & enlarge_liver['moderate'] & body_weakness['very_severe'] & joint_pain['mild'] & dizziness['severe'] & loss_of_appentite['mild'] & MP['moderate'], conclusion['very_severe'])
rule17 = ctrl.Rule(fever['mild'] & headache['very_severe'] & vomiting['moderate'] & nause['moderate'] & jaundice['mild'] & enlarge_liver['moderate'] & body_weakness['moderate'] & joint_pain['mild'] & dizziness['very_severe'] & loss_of_appentite['mild'] & MP['moderate'], conclusion['very_severe'])
rule18 = ctrl.Rule(fever['moderate'] & headache['very_severe'] & vomiting['mild'] & nause['very_severe'] & jaundice['severe'] & enlarge_liver['severe'] & body_weakness['severe'] & joint_pain['moderate'] & dizziness['very_severe'] & loss_of_appentite['very_severe'] & MP['severe'], conclusion['very_severe'])
rule19 = ctrl.Rule(fever['moderate'] & headache['moderate'] & vomiting['moderate'] & nause['moderate'] & jaundice['mild'] & enlarge_liver['mild'] & body_weakness['moderate'] & joint_pain['moderate'] & dizziness['moderate'] & loss_of_appentite['mild'] & MP['moderate'], conclusion['moderate'])
rule20 = ctrl.Rule(fever['very_severe'] & headache['severe'] & vomiting['severe'] & nause['severe'] & jaundice['severe'] & enlarge_liver['severe'] & body_weakness['severe'] & joint_pain['severe'] & dizziness['severe'] & loss_of_appentite['mild'] & MP['moderate'], conclusion['very_severe'])

# %%
conclusion_ctrl = ctrl.ControlSystem([rule1,rule2,rule3,rule4,rule5,rule6,rule7,rule8,rule9,rule10,rule11,rule12,rule13,rule14,rule15,rule16,rule17,rule18,rule19,rule20])
conclusion_ctrl.view()

# %%
conclusion_fis = ctrl.ControlSystemSimulation(conclusion_ctrl)
conclusion_fis.input['fever'] = 1
conclusion_fis.input['headache'] = 9
conclusion_fis.input['vomiting'] = 4
conclusion_fis.input['nause'] = 4
conclusion_fis.input['jaundice'] = 1
conclusion_fis.input['enlarge_liver'] = 4
conclusion_fis.input['body_weakness'] = 4
conclusion_fis.input['joint_pain'] = 1
conclusion_fis.input['dizziness'] = 9
conclusion_fis.input['loss_of_appentite'] = 1
conclusion_fis.input['MP'] = 4
conclusion_fis.compute()
print(conclusion_fis.output['conclusion'])
conclusion.view(sim = conclusion_fis)
# Out:
# 8.999999999999998
